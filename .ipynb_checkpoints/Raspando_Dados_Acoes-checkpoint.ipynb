# %%
import pandas_datareader as pdr
import datetime
import numpy as np

# %%
vale3 = pdr.get_data_yahoo("VALE3.SA",
                          start=datetime.datetime.now().date(),
                          end=datetime.datetime.now().date())

# %%
display(vale3.tail())
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-06-25  113.970001  111.400002  111.599998  112.400002  26050000
#
#              Adj Close
# Date
# 2021-06-25  112.400002

# %%
print(datetime.datetime.today())
# Out:
# 2021-06-26 13:16:17.884220

# %%
print(datetime.datetime(2020,10,1))
# Out:
# 2020-10-01 00:00:00

# %%
print()
# Out:
# 2021-06-26
